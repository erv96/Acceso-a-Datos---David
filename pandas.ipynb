# %%
import pandas as pd

# %% [markdown]
# Ejercicio
# Escribir programa que genere y muestre por pantalla un DataFrame con los datos de la tabla siguiente:
#
# Mes	Ventas	Gastos
#
# Enero	30500	22000
#
# Febrero	35600	23400
#
# Marzo	28300	18100
#
# Abril	33900	20700

# %%
datos = {'Mes':['Enero', 'Febrero', 'Marzo', 'Abril'], 'Ventas':[30500, 35600, 28300, 33900], 
         'Gastos':[22000, 23400, 18100, 20700]}
contab = pd.DataFrame(datos)
display(contabilidad)
# Out:
#        Mes  Ventas  Gastos
# 0    Enero   30500   22000
# 1  Febrero   35600   23400
# 2    Marzo   28300   18100
# 3    Abril   33900   20700

# %%
v_tot=g_tot=0
for ix,row in contab.iterrows():
    # print('ìndice=',ix,'fila=',row['Mes'])
    v_tot += row['Ventas']
    g_tot += row['Gastos']
print(v_tot,g_tot)
# Out:
# 128300 84200

# %%
# suma de columnas Ventas y Gastos
v_tot = contab['Ventas']+contab['Gastos']
print(v_tot)
# Out:
# 0    52500
# 1    59000
# 2    46400
# 3    54600
# dtype: int64

# %%
# totales de columnas
v_tot = contab[['Ventas','Gastos']].sum()
print(v_tot)
# Out:
# Ventas    128300
# Gastos     84200
# dtype: int64

# %%
# resta de columnas Ventas - Gastos
v_tot = contab['Ventas']-contab['Gastos']
print(v_tot)
# Out:
# 0     8500
# 1    12200
# 2    10200
# 3    13200
# dtype: int64

# %%
# suma de columnas
v_tot = contab['Ventas']-contab['Gastos']
print(v_tot)

# %% [markdown]
# El fichero cotizacion.csv contiene las cotizaciones de las empresas del IBEX35 con las siguientes columnas: nombre (nombre de la empresa), Final (precio de la acción al cierre de bolsa), Máximo (precio máximo de la acción durante la jornada), Mínimo (precio mínimo de la acción durante la jornada), volumen (Volumen al cierre de bolsa), Efectivo (capitalización al cierre en miles de euros). Construir una función que construya un DataFrame a partir del un fichero con el formato anterior y devuelva otro DataFrame con el mínimo, el máximo y la media de dada columna.

# %%
def resumen_cotizaciones(fichero):
    df = pd.read_csv(fichero, sep=';', decimal=',', thousands='.', index_col=0)
    return pd.DataFrame([df.min(), df.max(), df.mean()], index=['Mínimo', 'Máximo', 'Media'])

resumen_cotizaciones('cotizacion.csv')
# Out:
#                Final        Máximo        Mínimo       Volumen    Efectivo
# Mínimo      1.016500      4.067500      1.016500  1.221000e+03    2343.090
# Máximo  19705.000000  19875.000000  19675.000000  3.612969e+07  145765.440
# Media    2796.768757   3170.113357   3136.510471  4.252279e+06   31767.778

# %%
df
# Out:
#                    Final      Máximo      Mínimo   Volumen   Efectivo
# Nombre
# ACCIONA          95.9500     96.7500     94.4000     84962    8166.11
# ACERINOX       8668.0000   8672.0000   8468.0000     88599    7633.81
# ACS              37.2800     37.6600     37.2200    655982   24517.29
# AENA            167.1000    167.5000    166.1000    133738   22336.10
# AMADEUS          69.9600     70.6400     69.5600    640476   44795.47
# ARCELORMIT.   14152.0000  14318.0000     14.0800    702841    9989.65
# BA.SABADELL       1.0165   1033.0000      1.0165  12358512   12637.65
# BA.SANTANDER      4.0200      4.0675      4.0100  36129692  145765.44
# BANKIA         2249.0000   2262.0000   2224.0000   3024454    6803.54
# BANKINTER         6.5600   6604.0000   6522.0000   1375976    9030.20
# BBVA           5024.0000      5.0500   4969.0000  26447612  132560.15
# CAIXABANK      2763.0000   2806.0000   2762.0000  13031097   36239.22
# ...

# %%
df = pd.read_csv('cotizacion.csv', sep=';', decimal=',', thousands='.', index_col=0)
display(df.min(axis=0))
# Out:
# Final          1.0165
# Máximo         4.0675
# Mínimo         1.0165
# Volumen     1221.0000
# Efectivo    2343.0900
# dtype: float64

# %% [markdown]
# ###  Leer el dataset de Kaggle used cars y realizar los siguientes cálculos:
# - Mínimos por columnas
# - Máximos por columnas
# - Media por columnas

# %%
used.columns
# Out:
# Index(['Unnamed: 0', 'brand', 'model', 'price (eur)', 'engine', 'year',
#        'mileage (kms)', 'fuel', 'gearbox', 'location'],
#       dtype='object')

# %%
used = pd.read_csv('used_cars_data2.csv', sep=';')
used['total'] = used[['price (eur)','year', 'mileage (kms)']].sum(axis=1)
used
# Out:
#      Unnamed: 0       brand     model  price (eur)  \
# 0             0        SEAT     Ibiza         8990
# 1             1     Hyundai       i30         9990
# 2             2         BMW   Serie 5        13490
# 3             3  Volkswagen      Golf        24990
# 4             4        Opel     Corsa        10460
# ..          ...         ...       ...          ...
# 787         787  Volkswagen      Golf        13990
# 788         788         Kia  Sportage        24990
# 789         789      Abarth       500        17990
# 790         790  Volkswagen    Tiguan        14990
# 791         791       Dacia    Dokker        14390
#
#                                        engine  year  mileage (kms)      fuel  \
# 0                       SC 1.2 TSI 90cv Style  2016          67000  Gasolina
# 1                        1.6 CRDi 110cv Tecno  2014         104868    Diésel
# 2                                530d Touring  2011         137566    Diésel
# ...
